# %%
#Si queremos que las imágenes sean mostradas en una ventana emergente quitar el inline
# %matplotlib inline

# OpenCV-Python utiliza NumPy para el manejo de imágenes
import numpy as np
# cv2 es el módulo python para acceder a OpenCV 
import cv2 as cv
# Usamos las poderosas herramientas de graficación de matplotlib para mostrar imágenes, perfiles, histogramas, etc
import matplotlib.pyplot as plt

# %%
# img = cv.imread('mib-alien.jpg',cv.IMREAD_GRAYSCALE)
img1 = cv.imread('CoordCrom_1.png')
img = cv.cvtColor(img1,cv.COLOR_BGR2RGB)
imgR,imgG,imgB = cv.split(img)

# Imagen original
plt.figure(1)
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
div = (imgR + imgG + imgB)
auxR = np.uint8(imgR/div)
auxG = np.uint8(imgG/div)
auxB = np.uint8(imgB/div)
crom = cv.merge((auxR,auxG,auxB))
plt.figure(2)
plt.imshow(crom)
plt.show
# Out:
# <ipython-input-14-68509bf3072d>:2: RuntimeWarning: divide by zero encountered in true_divide
#   auxR = np.uint8(imgR/div)
# <ipython-input-14-68509bf3072d>:2: RuntimeWarning: invalid value encountered in true_divide
#   auxR = np.uint8(imgR/div)
# <ipython-input-14-68509bf3072d>:3: RuntimeWarning: divide by zero encountered in true_divide
#   auxG = np.uint8(imgG/div)
# <ipython-input-14-68509bf3072d>:3: RuntimeWarning: invalid value encountered in true_divide
#   auxG = np.uint8(imgG/div)
# <ipython-input-14-68509bf3072d>:4: RuntimeWarning: divide by zero encountered in true_divide
#   auxB = np.uint8(imgB/div)
# <ipython-input-14-68509bf3072d>:4: RuntimeWarning: invalid value encountered in true_divide
#   auxB = np.uint8(imgB/div)
# <function matplotlib.pyplot.show(*args, **kw)>
